# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler

# %%
df=pd.read_csv(r"D:\projectroot\data\raw\AirQualityData.csv")
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3448 entries, 0 to 3447
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   country        3448 non-null   str
#  1   state          3448 non-null   str
#  2   city           3448 non-null   str
#  3   station        3448 non-null   str
#  4   last_update    3448 non-null   str
#  5   latitude       3448 non-null   float64
#  6   longitude      3448 non-null   float64
#  7   pollutant_id   3448 non-null   str
#  8   pollutant_min  3278 non-null   float64
#  9   pollutant_max  3278 non-null   float64
#  10  pollutant_avg  3278 non-null   float64
# dtypes: float64(5), str(6)
# memory usage: 296.4 KB

# %%
df.describe()
count=df.isnull().sum()
count
# Out:
# country            0
# state              0
# city               0
# station            0
# last_update        0
# latitude           0
# longitude          0
# pollutant_id       0
# pollutant_min    170
# pollutant_max    170
# pollutant_avg    170
# dtype: int64

# %%
x=['country','state','city']
xx=df[x]
xx=le.fit_transform(xx)
df['country']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 3
#       1 x=['country','state','city']
#       2 xx=df[x]
# ----> 3 xx=le.fit_transform(xx)
#       4 df['country']
#
# File d:\projectroot\models\Lib\site-packages\sklearn\preprocessing\_label.py:120, in LabelEncoder.fit_transform(self, y)
#     107 def fit_transform(self, y):
#     108     """Fit label encoder and return encoded labels.
#     109
#     110     Parameters
#    (...)    118         Encoded labels.
#     119     """
# --> 120     y = column_or_1d(y, warn=True)
#     121     self.classes_, y = _unique(y, return_inverse=True)
#     122     return y
#
# File d:\projectroot\models\Lib\site-packages\sklearn\utils\validation.py:1447, in column_or_1d(y, dtype, input_name, warn, device)
#    1434         warnings.warn(
#    1435             (
# ...

# %%
x=['country','state','city','pollutant_id']
for i in x:
   le=LabelEncoder()
   xx=df[i]
   df[i]=le.fit_transform(xx)

# %%
scaler=MinMaxScaler()
df=scaler.fit_transform(df)
# Out:
# array([[0.        , 0.10344828, 0.7962963 , ..., 0.09966777, 0.21242485,
#         0.18210863],
#        [0.        , 0.10344828, 0.7962963 , ..., 0.03654485, 0.02805611,
#         0.04153355],
#        [0.        , 0.10344828, 0.7962963 , ..., 0.00664452, 0.00400802,
#         0.00638978],
#        ...,
#        [0.        , 1.        , 0.54444444, ..., 0.06312292, 0.08416834,
#         0.07348243],
#        [0.        , 1.        , 0.54444444, ..., 0.06312292, 0.06412826,
#         0.09265176],
#        [0.        , 1.        , 0.86666667, ...,        nan,        nan,
#                nan]], shape=(3448, 9))

# %%
df['last_update']=pd.to_datetime(df['last_update'],origin=)
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3448 entries, 0 to 3447
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   country        3448 non-null   str
#  1   state          3448 non-null   str
#  2   city           3448 non-null   str
#  3   station        3448 non-null   str
#  4   last_update    3448 non-null   datetime64[us]
#  5   latitude       3448 non-null   float64
#  6   longitude      3448 non-null   float64
#  7   pollutant_id   3448 non-null   str
#  8   pollutant_min  3278 non-null   float64
#  9   pollutant_max  3278 non-null   float64
#  10  pollutant_avg  3278 non-null   float64
# dtypes: datetime64[us](1), float64(5), str(5)
# memory usage: 296.4 KB
